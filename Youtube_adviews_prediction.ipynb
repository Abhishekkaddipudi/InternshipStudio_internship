# %%
#import the required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#downloading the dataset 
# !gdown 1Dv-HF10AUUA03AO_cQvar462eXawk0iQ
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Dv-HF10AUUA03AO_cQvar462eXawk0iQ
# To: /content/train.csv
# 100% 748k/748k [00:00<00:00, 143MB/s]

# %%
#load the dataset as pandas dataframe
df=pd.read_csv("/content/train.csv")

# %%
#sample of dataset
df.head()
# Out:
#        vidid  adview    views likes dislikes comment   published duration  \
# 0  VID_18655      40  1031602  8523      363    1095  2016-09-14  PT7M37S
# 1  VID_14135       2     1707    56        2       6  2016-10-01  PT9M30S
# 2   VID_2187       1     2023    25        0       2  2016-07-02  PT2M16S
# 3  VID_23096       6   620860   777      161     153  2016-07-27  PT4M22S
# 4  VID_10175       1      666     1        0       0  2016-06-29    PT31S
#
#   category
# 0        F
# 1        D
# 2        C
# 3        H
# 4        D

# %%
#dataset shape
df.shape
# Out:
# (14999, 9)

# %%
#dataset overall information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   vidid      14999 non-null  object
#  1   adview     14999 non-null  int64
#  2   views      14999 non-null  object
#  3   likes      14999 non-null  object
#  4   dislikes   14999 non-null  object
#  5   comment    14999 non-null  object
#  6   published  14999 non-null  object
#  7   duration   14999 non-null  object
#  8   category   14999 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 1.0+ MB

# %% [markdown]
# **Observation**
#
# 1. no null values
# 2. adview is only integer column other column are all of type object
# 3. likes,dislikes,comments and views column must be  of type integer
# 4. published column must be tranformed
# 5. category column is categorical features must be tranformed
# 6. duration column must be tranformed

# %%
df.describe()
# Out:
#              adview
# count  1.499900e+04
# mean   2.107791e+03
# std    5.237711e+04
# min    1.000000e+00
# 25%    1.000000e+00
# 50%    2.000000e+00
# 75%    6.000000e+00
# max    5.429665e+06

# %%
df.isnull().sum()
# Out:
# vidid        0
# adview       0
# views        0
# likes        0
# dislikes     0
# comment      0
# published    0
# duration     0
# category     0
# dtype: int64

# %%
df.isna().sum()
# Out:
# vidid        0
# adview       0
# views        0
# likes        0
# dislikes     0
# comment      0
# published    0
# duration     0
# category     0
# dtype: int64

# %%
#taking a backup of original data before performing tranformation
df_backup=df

# %%
#converting categorical nominal column to numerical nominal column
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
print(df["category"].unique())
df["category"]=LE.fit_transform(df["category"])
print(df["category"].unique())
# Out:
# ['F' 'D' 'C' 'H' 'E' 'B' 'G' 'A']
# [5 3 2 7 4 1 6 0]

# %%
df.head()
# Out:
#        vidid  adview    views likes dislikes comment   published duration  \
# 0  VID_18655      40  1031602  8523      363    1095  2016-09-14  PT7M37S
# 1  VID_14135       2     1707    56        2       6  2016-10-01  PT9M30S
# 2   VID_2187       1     2023    25        0       2  2016-07-02  PT2M16S
# 3  VID_23096       6   620860   777      161     153  2016-07-27  PT4M22S
# 4  VID_10175       1      666     1        0       0  2016-06-29    PT31S
#
#    category
# 0         5
# 1         3
# 2         2
# 3         7
# 4         3

# %%
# Removing "F" present in data
df=df[df.views!="F"]

# %%
df=df[df.likes!="F"]

# %%
df=df[df.dislikes!="F"]

# %%
df=df[df.comment!="F"]

# %%
#converting likes , dislikes ,views and comments as integer type

# %%
df.views=df.views.astype("int64")

# %%
df.likes=df.likes.astype("int64")

# %%
df.dislikes=df.dislikes.astype("int64")

# %%
df.comment=df.comment.astype("int64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14637 entries, 0 to 14998
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   vidid      14637 non-null  object
#  1   adview     14637 non-null  int64
#  2   views      14637 non-null  int64
#  3   likes      14637 non-null  int64
#  4   dislikes   14637 non-null  int64
#  5   comment    14637 non-null  int64
#  6   published  14637 non-null  object
#  7   duration   14637 non-null  object
#  8   category   14637 non-null  int64
# dtypes: int64(6), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# **Converted to integers**

# %%
vivid_colm=df["vidid"]

# %%
#regex expression to match hours minutes and seconds pattern
import re
def funsec(string):

  pattern = r'PT(?:(?P<hours>\d+)H)?((?P<minutes>\d+)M)?((?P<seconds>\d+)S)?'
  hours=0
  minutes=0
  seconds=0
  match = re.search(pattern, string)
  if match:
      hours = match.group('hours') if match.group('hours') else 0
      minutes = match.group('minutes') if match.group('minutes') else 0
      seconds = match.group('seconds') if match.group('seconds') else 0
      return int(hours)*3600+int(minutes)*60+int(seconds)

# %%
# Converting hours minutes and seconds
df["duration"]=df["duration"].apply(funsec)

# %%
df.head()
# Out:
#        vidid  adview    views  likes  dislikes  comment   published  duration  \
# 0  VID_18655      40  1031602   8523       363     1095  2016-09-14       457
# 1  VID_14135       2     1707     56         2        6  2016-10-01       570
# 2   VID_2187       1     2023     25         0        2  2016-07-02       136
# 3  VID_23096       6   620860    777       161      153  2016-07-27       262
# 4  VID_10175       1      666      1         0        0  2016-06-29        31
#
#    category
# 0         5
# 1         3
# 2         2
# 3         7
# 4         3

# %%
#Encoding the duration vivid and published columns
df["vidid"]=LE.fit_transform(df["vidid"])
df["published"]=LE.fit_transform(df["published"])

# %%
df.head()
# Out:
#    vidid  adview    views  likes  dislikes  comment  published  duration  \
# 0   5912      40  1031602   8523       363     1095       2168       457
# 1   2741       2     1707     56         2        6       2185       570
# 2   8138       1     2023     25         0        2       2094       136
# 3   9005       6   620860    777       161      153       2119       262
# 4    122       1      666      1         0        0       2091        31
#
#    category
# 0         5
# 1         3
# 2         2
# 3         7
# 4         3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14637 entries, 0 to 14998
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   vidid      14637 non-null  int64
#  1   adview     14637 non-null  int64
#  2   views      14637 non-null  int64
#  3   likes      14637 non-null  int64
#  4   dislikes   14637 non-null  int64
#  5   comment    14637 non-null  int64
#  6   published  14637 non-null  int64
#  7   duration   14637 non-null  int64
#  8   category   14637 non-null  int64
# dtypes: int64(9)
# memory usage: 1.1 MB

# %% [markdown]
# **Observation**
# 1. the column adview doesn't correalte much other columns
# 2. likes,dislikes , views and comments are highly correlated which understandable for youtube video

# %%
#Visulation
for i in df:
  if i !="category"and i !="published" and i !="vidid":
    plt.plot(df[i])
    plt.title(i)
    plt.show()
    print()

# %%
for i in df:
  if i =="category" or i =="published":
    plt.hist(df[i])
    plt.title(i)
    plt.show()

# %%
df=df[df.adview<2000000]

# %%
#checking the correlation among columns
df.corr()
# Out:
#               vidid    adview     views     likes  dislikes   comment  \
# vidid      1.000000 -0.031080 -0.047581 -0.128860 -0.076460 -0.081059
# adview    -0.031080  1.000000  0.031177  0.046541  0.016686  0.017631
# views     -0.047581  0.031177  1.000000  0.726599  0.730216  0.410597
# likes     -0.128860  0.046541  0.726599  1.000000  0.648631  0.651215
# dislikes  -0.076460  0.016686  0.730216  0.648631  1.000000  0.532588
# comment   -0.081059  0.017631  0.410597  0.651215  0.532588  1.000000
# published -0.144470  0.055657  0.020110  0.096941  0.043745  0.114253
# duration   0.006910 -0.019592  0.002563 -0.042518  0.001587 -0.037478
# category  -0.038917 -0.004910  0.032822 -0.009175  0.011355 -0.034107
#
#            published  duration  category
# vidid      -0.144470  0.006910 -0.038917
# adview      0.055657 -0.019592 -0.004910
# views       0.020110  0.002563  0.032822
# likes       0.096941 -0.042518 -0.009175
# dislikes    0.043745  0.001587  0.011355
# comment     0.114253 -0.037478 -0.034107
# published   1.000000  0.011976 -0.056814
# duration    0.011976  1.000000  0.049235
# category   -0.056814  0.049235  1.000000

# %%
f,ax=plt.subplots(figsize=(9, 9))
correlation=df.corr()
sns.heatmap(correlation,mask=np.zeros_like(correlation,dtype=np.bool),cmap=sns.diverging_palette(220,10,as_cmap=True),square=True,ax=ax,annot=True)
# Out:
# <ipython-input-65-f58c6bfa6240>:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   sns.heatmap(correlation,mask=np.zeros_like(correlation,dtype=np.bool),cmap=sns.diverging_palette(220,10,as_cmap=True),square=True,ax=ax,annot=True)
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
X_train,X_test,y_train,y_test=train_test_split(df.drop(["adview"],axis=1),df["adview"],test_size=0.2,random_state=42)

# %%
Scaler=MinMaxScaler()
X_train=Scaler.fit_transform(X_train)
X_test=Scaler.transform(X_test)

# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error, mean_squared_error
from catboost import CatBoostRegressor
import xgboost as xgb
from keras.models import Sequential
from keras.layers import Dense
import numpy as np


# Define the regression models and their corresponding hyperparameter grids
models = [
    (LinearRegression(), {}),
    (Ridge(), {'alpha': [0.1, 1, 10]}),
    (Lasso(), {'alpha': [0.1, 1, 10]}),
    (ElasticNet(), {'alpha': [0.1, 1, 10], 'l1_ratio': [0.2, 0.5, 0.8]}),
    (DecisionTreeRegressor(), {'max_depth': [None, 5, 10]}),
    (RandomForestRegressor(), {'n_estimators': [100, 200, 300], 'max_depth': [None, 5, 10]}),
    (GradientBoostingRegressor(), {'n_estimators': [100, 200, 300], 'learning_rate': [0.01, 0.1, 1.0]}),
    (AdaBoostRegressor(), {'n_estimators': [50, 100, 150], 'learning_rate': [0.01, 0.1, 1.0]}),
    (SVR(), {'kernel': ['linear', 'rbf'], 'C': [0.1, 1, 10]}),
    (CatBoostRegressor(silent=True), {'iterations': [100, 200, 300], 'learning_rate': [0.01, 0.1, 1.0]}),
    (xgb.XGBRegressor(), {'max_depth': [3, 5, 7], 'learning_rate': [0.01, 0.1, 1.0]}),
    (Sequential([Dense(64, activation='relu', input_shape=X_train.shape[1:]),Dense(64, activation='relu'),Dense(1)]), {})
]


# List to store the scoring results
Minmax_scoring_results = []

# Train and evaluate each model with hyperparameter tuning
for model, param_grid in models:
    if isinstance(model, Sequential):
        model.compile(loss='mean_squared_error', optimizer='adam')
        model.fit(X_train, y_train, epochs=100, verbose=0)
        y_pred = model.predict(X_test).flatten()
    else:
        grid_search = GridSearchCV(model, param_grid, scoring='neg_mean_absolute_error', cv=5,verbose=3)
        grid_search.fit(X_train, y_train)
        y_pred = grid_search.predict(X_test)
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    Minmax_scoring_results.append({'Model': type(model).__name__, 'Best Parameters': grid_search.best_params_, 'MAE': mae, 'MSE': mse, 'RMSE': rmse})

# Print the scoring results
for result in Minmax_scoring_results:
    print('Model:', result['Model'])
    print('Best Parameters:', result['Best Parameters'])
    print('MAE:', result['MAE'])
    print('MSE:', result['MSE'])
    print('RMSE:', result['RMSE'])
    print('-----------------------')
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END ..............................., score=-3830.455 total time=   0.0s
# [CV 2/5] END ..............................., score=-3492.952 total time=   0.0s
# [CV 3/5] END ..............................., score=-3596.922 total time=   0.0s
# [CV 4/5] END ..............................., score=-4149.382 total time=   0.0s
# [CV 5/5] END ..............................., score=-2897.613 total time=   0.0s
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5] END .....................alpha=0.1;, score=-3824.687 total time=   0.0s
# [CV 2/5] END .....................alpha=0.1;, score=-3489.870 total time=   0.0s
# [CV 3/5] END .....................alpha=0.1;, score=-3583.035 total time=   0.0s
# [CV 4/5] END .....................alpha=0.1;, score=-4142.967 total time=   0.0s
# [CV 5/5] END .....................alpha=0.1;, score=-2892.570 total time=   0.0s
# [CV 1/5] END .......................alpha=1;, score=-3799.641 total time=   0.0s
# [CV 2/5] END .......................alpha=1;, score=-3474.535 total time=   0.0s
# [CV 3/5] END .......................alpha=1;, score=-3527.291 total time=   0.0s
# [CV 4/5] END .......................alpha=1;, score=-4116.467 total time=   0.0s
# [CV 5/5] END .......................alpha=1;, score=-2863.839 total time=   0.0s
# [CV 1/5] END ......................alpha=10;, score=-3774.417 total time=   0.0s
# [CV 2/5] END ......................alpha=10;, score=-3439.116 total time=   0.0s
# [CV 3/5] END ......................alpha=10;, score=-3432.466 total time=   0.0s
# [CV 4/5] END ......................alpha=10;, score=-4065.264 total time=   0.0s
# [CV 5/5] END ......................alpha=10;, score=-2803.591 total time=   0.0s
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5] END .....................alpha=0.1;, score=-3829.089 total time=   0.0s
# [CV 2/5] END .....................alpha=0.1;, score=-3491.576 total time=   0.0s
# [CV 3/5] END .....................alpha=0.1;, score=-3594.196 total time=   0.0s
# [CV 4/5] END .....................alpha=0.1;, score=-4147.821 total time=   0.0s
# [CV 5/5] END .....................alpha=0.1;, score=-2896.149 total time=   0.0s
# [CV 1/5] END .......................alpha=1;, score=-3817.226 total time=   0.0s
# [CV 2/5] END .......................alpha=1;, score=-3479.796 total time=   0.0s
# [CV 3/5] END .......................alpha=1;, score=-3570.187 total time=   0.0s
# [CV 4/5] END .......................alpha=1;, score=-4134.408 total time=   0.0s
# [CV 5/5] END .......................alpha=1;, score=-2883.157 total time=   0.0s
# [CV 1/5] END ......................alpha=10;, score=-3756.402 total time=   0.0s
# [CV 2/5] END ......................alpha=10;, score=-3421.498 total time=   0.0s
# [CV 3/5] END ......................alpha=10;, score=-3445.666 total time=   0.0s
# [CV 4/5] END ......................alpha=10;, score=-4077.899 total time=   0.0s
# [CV 5/5] END ......................alpha=10;, score=-2807.978 total time=   0.0s
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END .......alpha=0.1, l1_ratio=0.2;, score=-3506.843 total time=   0.0s
# [CV 2/5] END .......alpha=0.1, l1_ratio=0.2;, score=-3162.356 total time=   0.0s
# [CV 3/5] END .......alpha=0.1, l1_ratio=0.2;, score=-3061.165 total time=   0.0s
# [CV 4/5] END .......alpha=0.1, l1_ratio=0.2;, score=-3825.228 total time=   0.0s
# [CV 5/5] END .......alpha=0.1, l1_ratio=0.2;, score=-2452.522 total time=   0.0s
# [CV 1/5] END .......alpha=0.1, l1_ratio=0.5;, score=-3525.503 total time=   0.0s
# [CV 2/5] END .......alpha=0.1, l1_ratio=0.5;, score=-3183.097 total time=   0.0s
# [CV 3/5] END .......alpha=0.1, l1_ratio=0.5;, score=-3094.707 total time=   0.0s
# [CV 4/5] END .......alpha=0.1, l1_ratio=0.5;, score=-3834.315 total time=   0.0s
# [CV 5/5] END .......alpha=0.1, l1_ratio=0.5;, score=-2476.075 total time=   0.0s
# [CV 1/5] END .......alpha=0.1, l1_ratio=0.8;, score=-3613.094 total time=   0.0s
# [CV 2/5] END .......alpha=0.1, l1_ratio=0.8;, score=-3275.766 total time=   0.0s
# [CV 3/5] END .......alpha=0.1, l1_ratio=0.8;, score=-3206.346 total time=   0.0s
# [CV 4/5] END .......alpha=0.1, l1_ratio=0.8;, score=-3898.576 total time=   0.0s
# [CV 5/5] END .......alpha=0.1, l1_ratio=0.8;, score=-2585.418 total time=   0.0s
# [CV 1/5] END .........alpha=1, l1_ratio=0.2;, score=-3537.040 total time=   0.0s
# [CV 2/5] END .........alpha=1, l1_ratio=0.2;, score=-3177.230 total time=   0.0s
# [CV 3/5] END .........alpha=1, l1_ratio=0.2;, score=-3054.506 total time=   0.0s
# [CV 4/5] END .........alpha=1, l1_ratio=0.2;, score=-3842.832 total time=   0.0s
# [CV 5/5] END .........alpha=1, l1_ratio=0.2;, score=-2467.638 total time=   0.0s
# [CV 1/5] END .........alpha=1, l1_ratio=0.5;, score=-3532.882 total time=   0.0s
# [CV 2/5] END .........alpha=1, l1_ratio=0.5;, score=-3175.068 total time=   0.0s
# [CV 3/5] END .........alpha=1, l1_ratio=0.5;, score=-3053.996 total time=   0.0s
# [CV 4/5] END .........alpha=1, l1_ratio=0.5;, score=-3840.773 total time=   0.0s
# [CV 5/5] END .........alpha=1, l1_ratio=0.5;, score=-2465.400 total time=   0.0s
# [CV 1/5] END .........alpha=1, l1_ratio=0.8;, score=-3519.890 total time=   0.0s
# [CV 2/5] END .........alpha=1, l1_ratio=0.8;, score=-3168.145 total time=   0.0s
# [CV 3/5] END .........alpha=1, l1_ratio=0.8;, score=-3052.993 total time=   0.0s
# [CV 4/5] END .........alpha=1, l1_ratio=0.8;, score=-3833.999 total time=   0.0s
# [CV 5/5] END .........alpha=1, l1_ratio=0.8;, score=-2458.271 total time=   0.0s
# [CV 1/5] END ........alpha=10, l1_ratio=0.2;, score=-3544.240 total time=   0.0s
# [CV 2/5] END ........alpha=10, l1_ratio=0.2;, score=-3180.923 total time=   0.0s
# [CV 3/5] END ........alpha=10, l1_ratio=0.2;, score=-3055.658 total time=   0.0s
# [CV 4/5] END ........alpha=10, l1_ratio=0.2;, score=-3846.365 total time=   0.0s
# [CV 5/5] END ........alpha=10, l1_ratio=0.2;, score=-2471.323 total time=   0.0s
# [CV 1/5] END ........alpha=10, l1_ratio=0.5;, score=-3543.747 total time=   0.0s
# [CV 2/5] END ........alpha=10, l1_ratio=0.5;, score=-3180.665 total time=   0.0s
# [CV 3/5] END ........alpha=10, l1_ratio=0.5;, score=-3055.567 total time=   0.0s
# [CV 4/5] END ........alpha=10, l1_ratio=0.5;, score=-3846.116 total time=   0.0s
# [CV 5/5] END ........alpha=10, l1_ratio=0.5;, score=-2471.075 total time=   0.0s
# [CV 1/5] END ........alpha=10, l1_ratio=0.8;, score=-3541.821 total time=   0.0s
# [CV 2/5] END ........alpha=10, l1_ratio=0.8;, score=-3179.660 total time=   0.0s
# [CV 3/5] END ........alpha=10, l1_ratio=0.8;, score=-3055.212 total time=   0.0s
# [CV 4/5] END ........alpha=10, l1_ratio=0.8;, score=-3845.146 total time=   0.0s
# [CV 5/5] END ........alpha=10, l1_ratio=0.8;, score=-2470.093 total time=   0.0s
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5] END ................max_depth=None;, score=-3282.310 total time=   0.2s
# [CV 2/5] END ................max_depth=None;, score=-2191.548 total time=   0.1s
# [CV 3/5] END ................max_depth=None;, score=-3181.140 total time=   0.1s
# [CV 4/5] END ................max_depth=None;, score=-4472.653 total time=   0.1s
# [CV 5/5] END ................max_depth=None;, score=-3385.165 total time=   0.1s
# [CV 1/5] END ...................max_depth=5;, score=-2842.580 total time=   0.0s
# [CV 2/5] END ...................max_depth=5;, score=-2378.508 total time=   0.0s
# [CV 3/5] END ...................max_depth=5;, score=-2247.853 total time=   0.0s
# [CV 4/5] END ...................max_depth=5;, score=-4135.622 total time=   0.0s
# [CV 5/5] END ...................max_depth=5;, score=-2854.123 total time=   0.0s
# [CV 1/5] END ..................max_depth=10;, score=-3086.999 total time=   0.1s
# [CV 2/5] END ..................max_depth=10;, score=-2045.053 total time=   0.1s
# [CV 3/5] END ..................max_depth=10;, score=-3677.896 total time=   0.1s
# [CV 4/5] END ..................max_depth=10;, score=-4178.261 total time=   0.1s
# [CV 5/5] END ..................max_depth=10;, score=-3313.893 total time=   0.1s
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END max_depth=None, n_estimators=100;, score=-2951.591 total time=   7.3s
# [CV 2/5] END max_depth=None, n_estimators=100;, score=-2671.573 total time=   7.4s
# [CV 3/5] END max_depth=None, n_estimators=100;, score=-3528.125 total time=   7.0s
# [CV 4/5] END max_depth=None, n_estimators=100;, score=-3682.982 total time=   7.3s
# [CV 5/5] END max_depth=None, n_estimators=100;, score=-2266.806 total time=   6.9s
# [CV 1/5] END max_depth=None, n_estimators=200;, score=-2896.590 total time=  14.5s
# [CV 2/5] END max_depth=None, n_estimators=200;, score=-2940.302 total time=  13.7s
# [CV 3/5] END max_depth=None, n_estimators=200;, score=-3309.580 total time=  14.4s
# [CV 4/5] END max_depth=None, n_estimators=200;, score=-3686.629 total time=  14.2s
# [CV 5/5] END max_depth=None, n_estimators=200;, score=-2269.385 total time=  14.2s
# [CV 1/5] END max_depth=None, n_estimators=300;, score=-2906.747 total time=  21.3s
# [CV 2/5] END max_depth=None, n_estimators=300;, score=-2802.313 total time=  20.6s
# [CV 3/5] END max_depth=None, n_estimators=300;, score=-3395.029 total time=  21.8s
# [CV 4/5] END max_depth=None, n_estimators=300;, score=-3574.068 total time=  21.4s
# [CV 5/5] END max_depth=None, n_estimators=300;, score=-2291.846 total time=  20.8s
# [CV 1/5] END .max_depth=5, n_estimators=100;, score=-2922.153 total time=   2.2s
# [CV 2/5] END .max_depth=5, n_estimators=100;, score=-3070.445 total time=   1.9s
# [CV 3/5] END .max_depth=5, n_estimators=100;, score=-3335.311 total time=   1.9s
# [CV 4/5] END .max_depth=5, n_estimators=100;, score=-3797.986 total time=   1.9s
# [CV 5/5] END .max_depth=5, n_estimators=100;, score=-2283.356 total time=   1.9s
# [CV 1/5] END .max_depth=5, n_estimators=200;, score=-2932.416 total time=   4.1s
# [CV 2/5] END .max_depth=5, n_estimators=200;, score=-3037.341 total time=   3.8s
# [CV 3/5] END .max_depth=5, n_estimators=200;, score=-3309.186 total time=   3.8s
# [CV 4/5] END .max_depth=5, n_estimators=200;, score=-3789.587 total time=   4.1s
# [CV 5/5] END .max_depth=5, n_estimators=200;, score=-2191.955 total time=   3.8s
# [CV 1/5] END .max_depth=5, n_estimators=300;, score=-2909.458 total time=   5.7s
# [CV 2/5] END .max_depth=5, n_estimators=300;, score=-3052.790 total time=   5.9s
# [CV 3/5] END .max_depth=5, n_estimators=300;, score=-3315.176 total time=   5.7s
# [CV 4/5] END .max_depth=5, n_estimators=300;, score=-3824.132 total time=   6.3s
# [CV 5/5] END .max_depth=5, n_estimators=300;, score=-2276.093 total time=   5.6s
# [CV 1/5] END max_depth=10, n_estimators=100;, score=-2887.982 total time=   3.8s
# [CV 2/5] END max_depth=10, n_estimators=100;, score=-2900.284 total time=   3.4s
# [CV 3/5] END max_depth=10, n_estimators=100;, score=-3453.558 total time=   3.5s
# [CV 4/5] END max_depth=10, n_estimators=100;, score=-3685.499 total time=   3.8s
# [CV 5/5] END max_depth=10, n_estimators=100;, score=-2412.911 total time=   3.5s
# [CV 1/5] END max_depth=10, n_estimators=200;, score=-2916.677 total time=   7.2s
# [CV 2/5] END max_depth=10, n_estimators=200;, score=-2849.928 total time=   7.0s
# [CV 3/5] END max_depth=10, n_estimators=200;, score=-3356.486 total time=   7.3s
# [CV 4/5] END max_depth=10, n_estimators=200;, score=-3586.297 total time=   7.0s
# [CV 5/5] END max_depth=10, n_estimators=200;, score=-2208.992 total time=   7.3s
# [CV 1/5] END max_depth=10, n_estimators=300;, score=-2875.548 total time=  10.8s
# [CV 2/5] END max_depth=10, n_estimators=300;, score=-2829.224 total time=  10.6s
# [CV 3/5] END max_depth=10, n_estimators=300;, score=-3197.843 total time=  10.8s
# [CV 4/5] END max_depth=10, n_estimators=300;, score=-3635.157 total time=  10.8s
# [CV 5/5] END max_depth=10, n_estimators=300;, score=-2228.371 total time=  10.5s
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END learning_rate=0.01, n_estimators=100;, score=-3374.379 total time=   1.8s
# [CV 2/5] END learning_rate=0.01, n_estimators=100;, score=-3013.504 total time=   1.8s
# [CV 3/5] END learning_rate=0.01, n_estimators=100;, score=-3315.507 total time=   1.8s
# [CV 4/5] END learning_rate=0.01, n_estimators=100;, score=-4165.251 total time=   1.8s
# [CV 5/5] END learning_rate=0.01, n_estimators=100;, score=-2284.363 total time=   1.8s
# [CV 1/5] END learning_rate=0.01, n_estimators=200;, score=-3277.795 total time=   3.8s
# [CV 2/5] END learning_rate=0.01, n_estimators=200;, score=-2911.322 total time=   3.5s
# [CV 3/5] END learning_rate=0.01, n_estimators=200;, score=-3443.180 total time=   3.5s
# [CV 4/5] END learning_rate=0.01, n_estimators=200;, score=-4289.864 total time=   3.8s
# [CV 5/5] END learning_rate=0.01, n_estimators=200;, score=-2185.325 total time=   3.5s
# [CV 1/5] END learning_rate=0.01, n_estimators=300;, score=-3159.005 total time=   5.3s
# [CV 2/5] END learning_rate=0.01, n_estimators=300;, score=-2841.537 total time=   5.5s
# [CV 3/5] END learning_rate=0.01, n_estimators=300;, score=-3400.239 total time=   5.3s
# [CV 4/5] END learning_rate=0.01, n_estimators=300;, score=-4426.364 total time=   5.5s
# [CV 5/5] END learning_rate=0.01, n_estimators=300;, score=-2090.479 total time=   5.3s
# [CV 1/5] END learning_rate=0.1, n_estimators=100;, score=-2992.658 total time=   1.8s
# [CV 2/5] END learning_rate=0.1, n_estimators=100;, score=-3039.636 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, n_estimators=100;, score=-3382.306 total time=   1.9s
# [CV 4/5] END learning_rate=0.1, n_estimators=100;, score=-4288.943 total time=   1.8s
# [CV 5/5] END learning_rate=0.1, n_estimators=100;, score=-2096.783 total time=   1.7s
# [CV 1/5] END learning_rate=0.1, n_estimators=200;, score=-3086.259 total time=   3.5s
# [CV 2/5] END learning_rate=0.1, n_estimators=200;, score=-2963.231 total time=   3.8s
# [CV 3/5] END learning_rate=0.1, n_estimators=200;, score=-3374.131 total time=   3.5s
# [CV 4/5] END learning_rate=0.1, n_estimators=200;, score=-4444.000 total time=   3.5s
# [CV 5/5] END learning_rate=0.1, n_estimators=200;, score=-2273.815 total time=   3.6s
# [CV 1/5] END learning_rate=0.1, n_estimators=300;, score=-3145.046 total time=   5.4s
# [CV 2/5] END learning_rate=0.1, n_estimators=300;, score=-3201.632 total time=   5.3s
# [CV 3/5] END learning_rate=0.1, n_estimators=300;, score=-3329.592 total time=   5.5s
# [CV 4/5] END learning_rate=0.1, n_estimators=300;, score=-4533.799 total time=   5.2s
# [CV 5/5] END learning_rate=0.1, n_estimators=300;, score=-2376.257 total time=   5.5s
# [CV 1/5] END learning_rate=1.0, n_estimators=100;, score=-3781.647 total time=   1.8s
# [CV 2/5] END learning_rate=1.0, n_estimators=100;, score=-5099.500 total time=   1.8s
# [CV 3/5] END learning_rate=1.0, n_estimators=100;, score=-3892.752 total time=   1.8s
# [CV 4/5] END learning_rate=1.0, n_estimators=100;, score=-5399.058 total time=   1.8s
# [CV 5/5] END learning_rate=1.0, n_estimators=100;, score=-3762.025 total time=   1.9s
# [CV 1/5] END learning_rate=1.0, n_estimators=200;, score=-3854.683 total time=   3.6s
# [CV 2/5] END learning_rate=1.0, n_estimators=200;, score=-5212.469 total time=   3.5s
# [CV 3/5] END learning_rate=1.0, n_estimators=200;, score=-4165.755 total time=   3.5s
# [CV 4/5] END learning_rate=1.0, n_estimators=200;, score=-5939.805 total time=   3.8s
# [CV 5/5] END learning_rate=1.0, n_estimators=200;, score=-4092.232 total time=   3.5s
# [CV 1/5] END learning_rate=1.0, n_estimators=300;, score=-3904.919 total time=   5.4s
# [CV 2/5] END learning_rate=1.0, n_estimators=300;, score=-5219.024 total time=   5.4s
# [CV 3/5] END learning_rate=1.0, n_estimators=300;, score=-4189.589 total time=   5.2s
# [CV 4/5] END learning_rate=1.0, n_estimators=300;, score=-5874.536 total time=   5.8s
# [CV 5/5] END learning_rate=1.0, n_estimators=300;, score=-4267.299 total time=   5.2s
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END learning_rate=0.01, n_estimators=50;, score=-3017.176 total time=   1.0s
# [CV 2/5] END learning_rate=0.01, n_estimators=50;, score=-2727.137 total time=   0.9s
# [CV 3/5] END learning_rate=0.01, n_estimators=50;, score=-2620.358 total time=   0.9s
# [CV 4/5] END learning_rate=0.01, n_estimators=50;, score=-4206.692 total time=   0.9s
# [CV 5/5] END learning_rate=0.01, n_estimators=50;, score=-2074.549 total time=   0.9s
# [CV 1/5] END learning_rate=0.01, n_estimators=100;, score=-3161.624 total time=   1.9s
# [CV 2/5] END learning_rate=0.01, n_estimators=100;, score=-3177.156 total time=   1.9s
# [CV 3/5] END learning_rate=0.01, n_estimators=100;, score=-3013.410 total time=   1.9s
# [CV 4/5] END learning_rate=0.01, n_estimators=100;, score=-4589.015 total time=   2.2s
# [CV 5/5] END learning_rate=0.01, n_estimators=100;, score=-2274.686 total time=   1.9s
# [CV 1/5] END learning_rate=0.01, n_estimators=150;, score=-4024.357 total time=   2.8s
# [CV 2/5] END learning_rate=0.01, n_estimators=150;, score=-3740.754 total time=   2.8s
# [CV 3/5] END learning_rate=0.01, n_estimators=150;, score=-3406.082 total time=   3.0s
# [CV 4/5] END learning_rate=0.01, n_estimators=150;, score=-5050.775 total time=   3.0s
# [CV 5/5] END learning_rate=0.01, n_estimators=150;, score=-2640.648 total time=   2.8s
# [CV 1/5] END learning_rate=0.1, n_estimators=50;, score=-5194.761 total time=   0.9s
# [CV 2/5] END learning_rate=0.1, n_estimators=50;, score=-5066.922 total time=   0.9s
# [CV 3/5] END learning_rate=0.1, n_estimators=50;, score=-5367.623 total time=   0.9s
# [CV 4/5] END learning_rate=0.1, n_estimators=50;, score=-6460.548 total time=   0.9s
# [CV 5/5] END learning_rate=0.1, n_estimators=50;, score=-4987.755 total time=   0.9s
# [CV 1/5] END learning_rate=0.1, n_estimators=100;, score=-6966.168 total time=   1.8s
# [CV 2/5] END learning_rate=0.1, n_estimators=100;, score=-7865.606 total time=   1.7s
# [CV 3/5] END learning_rate=0.1, n_estimators=100;, score=-8158.850 total time=   1.6s
# [CV 4/5] END learning_rate=0.1, n_estimators=100;, score=-10534.176 total time=   1.6s
# [CV 5/5] END learning_rate=0.1, n_estimators=100;, score=-9118.053 total time=   1.5s
# [CV 1/5] END learning_rate=0.1, n_estimators=150;, score=-9337.543 total time=   2.2s
# [CV 2/5] END learning_rate=0.1, n_estimators=150;, score=-10285.629 total time=   2.0s
# [CV 3/5] END learning_rate=0.1, n_estimators=150;, score=-12325.340 total time=   2.4s
# [CV 4/5] END learning_rate=0.1, n_estimators=150;, score=-15452.532 total time=   2.2s
# [CV 5/5] END learning_rate=0.1, n_estimators=150;, score=-10168.574 total time=   2.1s
# [CV 1/5] END learning_rate=1.0, n_estimators=50;, score=-14719.861 total time=   0.3s
# [CV 2/5] END learning_rate=1.0, n_estimators=50;, score=-48211.614 total time=   0.5s
# [CV 3/5] END learning_rate=1.0, n_estimators=50;, score=-51270.898 total time=   0.5s
# [CV 4/5] END learning_rate=1.0, n_estimators=50;, score=-37866.809 total time=   0.5s
# [CV 5/5] END learning_rate=1.0, n_estimators=50;, score=-36236.826 total time=   0.4s
# [CV 1/5] END learning_rate=1.0, n_estimators=100;, score=-39031.736 total time=   0.7s
# [CV 2/5] END learning_rate=1.0, n_estimators=100;, score=-145770.693 total time=   0.9s
# [CV 3/5] END learning_rate=1.0, n_estimators=100;, score=-74294.003 total time=   0.6s
# [CV 4/5] END learning_rate=1.0, n_estimators=100;, score=-85300.579 total time=   0.9s
# [CV 5/5] END learning_rate=1.0, n_estimators=100;, score=-44375.959 total time=   0.5s
# [CV 1/5] END learning_rate=1.0, n_estimators=150;, score=-38037.940 total time=   1.2s
# [CV 2/5] END learning_rate=1.0, n_estimators=150;, score=-151833.656 total time=   1.3s
# [CV 3/5] END learning_rate=1.0, n_estimators=150;, score=-111472.127 total time=   0.8s
# [CV 4/5] END learning_rate=1.0, n_estimators=150;, score=-34471.210 total time=   0.4s
# [CV 5/5] END learning_rate=1.0, n_estimators=150;, score=-24698.201 total time=   0.4s
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5] END ..........C=0.1, kernel=linear;, score=-2127.953 total time=   2.3s
# [CV 2/5] END ..........C=0.1, kernel=linear;, score=-1626.767 total time=   2.2s
# [CV 3/5] END ..........C=0.1, kernel=linear;, score=-1526.948 total time=   3.1s
# [CV 4/5] END ..........C=0.1, kernel=linear;, score=-2489.113 total time=   2.3s
# [CV 5/5] END ...........C=0.1, kernel=linear;, score=-695.454 total time=   2.2s
# [CV 1/5] END .............C=0.1, kernel=rbf;, score=-2127.934 total time=   3.6s
# [CV 2/5] END .............C=0.1, kernel=rbf;, score=-1626.745 total time=   4.4s
# [CV 3/5] END .............C=0.1, kernel=rbf;, score=-1526.925 total time=   3.6s
# [CV 4/5] END .............C=0.1, kernel=rbf;, score=-2489.092 total time=   3.6s
# [CV 5/5] END ..............C=0.1, kernel=rbf;, score=-695.439 total time=   4.4s
# [CV 1/5] END ............C=1, kernel=linear;, score=-2127.885 total time=   2.4s
# [CV 2/5] END ............C=1, kernel=linear;, score=-1626.688 total time=   2.4s
# [CV 3/5] END ............C=1, kernel=linear;, score=-1526.855 total time=   2.4s
# [CV 4/5] END ............C=1, kernel=linear;, score=-2489.049 total time=   2.6s
# [CV 5/5] END .............C=1, kernel=linear;, score=-695.370 total time=   3.1s
# [CV 1/5] END ...............C=1, kernel=rbf;, score=-2127.848 total time=   3.7s
# [CV 2/5] END ...............C=1, kernel=rbf;, score=-1626.638 total time=   3.6s
# [CV 3/5] END ...............C=1, kernel=rbf;, score=-1526.823 total time=   4.4s
# [CV 4/5] END ...............C=1, kernel=rbf;, score=-2489.007 total time=   3.7s
# [CV 5/5] END ................C=1, kernel=rbf;, score=-695.341 total time=   3.6s
# [CV 1/5] END ...........C=10, kernel=linear;, score=-2127.825 total time=   3.4s
# [CV 2/5] END ...........C=10, kernel=linear;, score=-1626.581 total time=   2.6s
# [CV 3/5] END ...........C=10, kernel=linear;, score=-1526.785 total time=   2.6s
# [CV 4/5] END ...........C=10, kernel=linear;, score=-2489.023 total time=   2.6s
# [CV 5/5] END ............C=10, kernel=linear;, score=-695.260 total time=   3.1s
# [CV 1/5] END ..............C=10, kernel=rbf;, score=-2127.766 total time=   4.0s
# [CV 2/5] END ..............C=10, kernel=rbf;, score=-1626.477 total time=   3.8s
# [CV 3/5] END ..............C=10, kernel=rbf;, score=-1526.703 total time=   4.5s
# [CV 4/5] END ..............C=10, kernel=rbf;, score=-2488.919 total time=   3.9s
# [CV 5/5] END ...............C=10, kernel=rbf;, score=-695.193 total time=   3.8s
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END iterations=100, learning_rate=0.01;, score=-3431.701 total time=   0.3s
# [CV 2/5] END iterations=100, learning_rate=0.01;, score=-2999.139 total time=   0.3s
# [CV 3/5] END iterations=100, learning_rate=0.01;, score=-3079.681 total time=   0.3s
# [CV 4/5] END iterations=100, learning_rate=0.01;, score=-3759.907 total time=   0.3s
# [CV 5/5] END iterations=100, learning_rate=0.01;, score=-2348.464 total time=   0.3s
# [CV 1/5] END iterations=100, learning_rate=0.1;, score=-3349.678 total time=   0.3s
# [CV 2/5] END iterations=100, learning_rate=0.1;, score=-2758.761 total time=   0.3s
# [CV 3/5] END iterations=100, learning_rate=0.1;, score=-3333.953 total time=   0.3s
# [CV 4/5] END iterations=100, learning_rate=0.1;, score=-3644.281 total time=   0.3s
# [CV 5/5] END iterations=100, learning_rate=0.1;, score=-2490.939 total time=   0.3s
# [CV 1/5] END iterations=100, learning_rate=1.0;, score=-3884.838 total time=   0.3s
# [CV 2/5] END iterations=100, learning_rate=1.0;, score=-3828.023 total time=   0.3s
# [CV 3/5] END iterations=100, learning_rate=1.0;, score=-4250.441 total time=   0.3s
# [CV 4/5] END iterations=100, learning_rate=1.0;, score=-4434.694 total time=   0.3s
# [CV 5/5] END iterations=100, learning_rate=1.0;, score=-4351.013 total time=   0.3s
# [CV 1/5] END iterations=200, learning_rate=0.01;, score=-3371.684 total time=   0.5s
# [CV 2/5] END iterations=200, learning_rate=0.01;, score=-2909.440 total time=   0.5s
# [CV 3/5] END iterations=200, learning_rate=0.01;, score=-3089.968 total time=   0.5s
# [CV 4/5] END iterations=200, learning_rate=0.01;, score=-3724.929 total time=   0.5s
# [CV 5/5] END iterations=200, learning_rate=0.01;, score=-2303.664 total time=   0.5s
# [CV 1/5] END iterations=200, learning_rate=0.1;, score=-3225.583 total time=   0.5s
# [CV 2/5] END iterations=200, learning_rate=0.1;, score=-2816.960 total time=   0.5s
# [CV 3/5] END iterations=200, learning_rate=0.1;, score=-3387.946 total time=   1.2s
# [CV 4/5] END iterations=200, learning_rate=0.1;, score=-3539.094 total time=   0.7s
# [CV 5/5] END iterations=200, learning_rate=0.1;, score=-2605.538 total time=   0.5s
# [CV 1/5] END iterations=200, learning_rate=1.0;, score=-3913.634 total time=   0.5s
# [CV 2/5] END iterations=200, learning_rate=1.0;, score=-3995.613 total time=   0.5s
# [CV 3/5] END iterations=200, learning_rate=1.0;, score=-4271.861 total time=   0.5s
# [CV 4/5] END iterations=200, learning_rate=1.0;, score=-4601.224 total time=   0.5s
# [CV 5/5] END iterations=200, learning_rate=1.0;, score=-4394.733 total time=   0.5s
# [CV 1/5] END iterations=300, learning_rate=0.01;, score=-3325.595 total time=   0.7s
# [CV 2/5] END iterations=300, learning_rate=0.01;, score=-2853.072 total time=   0.7s
# [CV 3/5] END iterations=300, learning_rate=0.01;, score=-3129.608 total time=   0.7s
# [CV 4/5] END iterations=300, learning_rate=0.01;, score=-3707.857 total time=   0.7s
# [CV 5/5] END iterations=300, learning_rate=0.01;, score=-2289.647 total time=   0.7s
# [CV 1/5] END iterations=300, learning_rate=0.1;, score=-3255.388 total time=   0.7s
# [CV 2/5] END iterations=300, learning_rate=0.1;, score=-2821.784 total time=   0.7s
# [CV 3/5] END iterations=300, learning_rate=0.1;, score=-3293.652 total time=   0.7s
# [CV 4/5] END iterations=300, learning_rate=0.1;, score=-3474.107 total time=   0.7s
# [CV 5/5] END iterations=300, learning_rate=0.1;, score=-2572.082 total time=   1.4s
# [CV 1/5] END iterations=300, learning_rate=1.0;, score=-3953.573 total time=   1.0s
# [CV 2/5] END iterations=300, learning_rate=1.0;, score=-4066.253 total time=   0.7s
# [CV 3/5] END iterations=300, learning_rate=1.0;, score=-4273.530 total time=   0.7s
# [CV 4/5] END iterations=300, learning_rate=1.0;, score=-4667.639 total time=   0.7s
# [CV 5/5] END iterations=300, learning_rate=1.0;, score=-4398.133 total time=   0.7s
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END learning_rate=0.01, max_depth=3;, score=-2843.741 total time=   0.4s
# [CV 2/5] END learning_rate=0.01, max_depth=3;, score=-2444.428 total time=   0.4s
# [CV 3/5] END learning_rate=0.01, max_depth=3;, score=-2349.795 total time=   0.4s
# [CV 4/5] END learning_rate=0.01, max_depth=3;, score=-3465.416 total time=   0.3s
# [CV 5/5] END learning_rate=0.01, max_depth=3;, score=-1625.936 total time=   0.3s
# [CV 1/5] END learning_rate=0.01, max_depth=5;, score=-2582.077 total time=   0.6s
# [CV 2/5] END learning_rate=0.01, max_depth=5;, score=-2083.259 total time=   0.6s
# [CV 3/5] END learning_rate=0.01, max_depth=5;, score=-2209.982 total time=   0.6s
# [CV 4/5] END learning_rate=0.01, max_depth=5;, score=-3268.971 total time=   0.6s
# [CV 5/5] END learning_rate=0.01, max_depth=5;, score=-1894.028 total time=   0.6s
# [CV 1/5] END learning_rate=0.01, max_depth=7;, score=-2469.854 total time=   0.9s
# [CV 2/5] END learning_rate=0.01, max_depth=7;, score=-1922.423 total time=   2.1s
# [CV 3/5] END learning_rate=0.01, max_depth=7;, score=-2008.135 total time=   0.9s
# [CV 4/5] END learning_rate=0.01, max_depth=7;, score=-3186.072 total time=   0.9s
# [CV 5/5] END learning_rate=0.01, max_depth=7;, score=-1794.338 total time=   0.9s
# [CV 1/5] END learning_rate=0.1, max_depth=3;, score=-3162.129 total time=   0.3s
# [CV 2/5] END learning_rate=0.1, max_depth=3;, score=-2668.970 total time=   0.3s
# [CV 3/5] END learning_rate=0.1, max_depth=3;, score=-2806.153 total time=   0.4s
# [CV 4/5] END learning_rate=0.1, max_depth=3;, score=-4575.327 total time=   0.4s
# [CV 5/5] END learning_rate=0.1, max_depth=3;, score=-2147.322 total time=   0.4s
# [CV 1/5] END learning_rate=0.1, max_depth=5;, score=-2908.347 total time=   0.6s
# [CV 2/5] END learning_rate=0.1, max_depth=5;, score=-2416.303 total time=   0.6s
# [CV 3/5] END learning_rate=0.1, max_depth=5;, score=-2718.189 total time=   0.6s
# [CV 4/5] END learning_rate=0.1, max_depth=5;, score=-4283.279 total time=   0.6s
# [CV 5/5] END learning_rate=0.1, max_depth=5;, score=-2702.778 total time=   0.6s
# [CV 1/5] END learning_rate=0.1, max_depth=7;, score=-2811.829 total time=   0.9s
# [CV 2/5] END learning_rate=0.1, max_depth=7;, score=-2485.617 total time=   1.0s
# [CV 3/5] END learning_rate=0.1, max_depth=7;, score=-2764.348 total time=   2.1s
# [CV 4/5] END learning_rate=0.1, max_depth=7;, score=-4331.747 total time=   0.9s
# [CV 5/5] END learning_rate=0.1, max_depth=7;, score=-3047.339 total time=   0.9s
# [CV 1/5] END learning_rate=1.0, max_depth=3;, score=-4401.804 total time=   0.4s
# [CV 2/5] END learning_rate=1.0, max_depth=3;, score=-4229.923 total time=   0.3s
# [CV 3/5] END learning_rate=1.0, max_depth=3;, score=-4630.042 total time=   0.4s
# [CV 4/5] END learning_rate=1.0, max_depth=3;, score=-5687.255 total time=   0.4s
# [CV 5/5] END learning_rate=1.0, max_depth=3;, score=-4107.639 total time=   0.4s
# [CV 1/5] END learning_rate=1.0, max_depth=5;, score=-3905.234 total time=   0.6s
# [CV 2/5] END learning_rate=1.0, max_depth=5;, score=-3639.988 total time=   0.6s
# [CV 3/5] END learning_rate=1.0, max_depth=5;, score=-3663.002 total time=   0.6s
# [CV 4/5] END learning_rate=1.0, max_depth=5;, score=-5144.115 total time=   0.6s
# [CV 5/5] END learning_rate=1.0, max_depth=5;, score=-4047.189 total time=   0.6s
# [CV 1/5] END learning_rate=1.0, max_depth=7;, score=-3557.029 total time=   1.0s
# [CV 2/5] END learning_rate=1.0, max_depth=7;, score=-3166.549 total time=   0.9s
# [CV 3/5] END learning_rate=1.0, max_depth=7;, score=-3943.366 total time=   2.1s
# [CV 4/5] END learning_rate=1.0, max_depth=7;, score=-4953.355 total time=   0.9s
# [CV 5/5] END learning_rate=1.0, max_depth=7;, score=-4000.414 total time=   0.9s
# 92/92 [==============================] - 0s 775us/step
# Model: LinearRegression
# Best Parameters: {}
# MAE: 3573.904714351931
# MSE: 831009504.5169327
# RMSE: 28827.235464347475
# -----------------------
# Model: Ridge
# Best Parameters: {'alpha': 10}
# MAE: 3501.157105353348
# MSE: 828493863.3969556
# RMSE: 28783.569330382838
# -----------------------
# Model: Lasso
# Best Parameters: {'alpha': 10}
# MAE: 3490.7772136117965
# MSE: 829588911.3230046
# RMSE: 28802.58515000007
# -----------------------
# Model: ElasticNet
# Best Parameters: {'alpha': 0.1, 'l1_ratio': 0.2}
# MAE: 3170.0336647638605
# MSE: 828341699.965029
# RMSE: 28780.925974767193
# -----------------------
# Model: DecisionTreeRegressor
# Best Parameters: {'max_depth': 5}
# MAE: 3571.910012754181
# MSE: 1946511811.4819949
# RMSE: 44119.29069559023
# -----------------------
# Model: RandomForestRegressor
# Best Parameters: {'max_depth': 10, 'n_estimators': 300}
# MAE: 2725.71395829414
# MSE: 559312901.5829275
# RMSE: 23649.797072764228
# -----------------------
# Model: GradientBoostingRegressor
# Best Parameters: {'learning_rate': 0.1, 'n_estimators': 100}
# MAE: 3435.9531262785817
# MSE: 1203068171.5213916
# RMSE: 34685.273121620245
# -----------------------
# Model: AdaBoostRegressor
# Best Parameters: {'learning_rate': 0.01, 'n_estimators': 50}
# MAE: 2917.8888130402083
# MSE: 822769076.6660641
# RMSE: 28683.951552498205
# -----------------------
# Model: SVR
# Best Parameters: {'C': 10, 'kernel': 'rbf'}
# MAE: 1696.8060419155854
# MSE: 833685335.9860126
# RMSE: 28873.60968057185
# -----------------------
# Model: CatBoostRegressor
# Best Parameters: {'iterations': 300, 'learning_rate': 0.01}
# MAE: 3018.869101006371
# MSE: 722894505.7150996
# RMSE: 26886.697560598615
# -----------------------
# Model: XGBRegressor
# Best Parameters: {'learning_rate': 0.01, 'max_depth': 7}
# MAE: 2392.4790853262357
# MSE: 800384911.6210924
# RMSE: 28291.074769635256
# -----------------------
# Model: Sequential
# Best Parameters: {'learning_rate': 0.01, 'max_depth': 7}
# MAE: 3237.478904187842
# MSE: 824982096.9750043
# RMSE: 28722.50157933679
# -----------------------

# %%
Result_df=pd.DataFrame.from_dict(Minmax_scoring_results)

# %%
Result_df
# Out:
#                         Model                              Best Parameters  \
# 0            LinearRegression                                           {}
# 1                       Ridge                                {'alpha': 10}
# 2                       Lasso                                {'alpha': 10}
# 3                  ElasticNet              {'alpha': 0.1, 'l1_ratio': 0.2}
# 4       DecisionTreeRegressor                             {'max_depth': 5}
# 5       RandomForestRegressor       {'max_depth': 10, 'n_estimators': 300}
# 6   GradientBoostingRegressor  {'learning_rate': 0.1, 'n_estimators': 100}
# 7           AdaBoostRegressor  {'learning_rate': 0.01, 'n_estimators': 50}
# 8                         SVR                   {'C': 10, 'kernel': 'rbf'}
# 9           CatBoostRegressor   {'iterations': 300, 'learning_rate': 0.01}
# 10               XGBRegressor      {'learning_rate': 0.01, 'max_depth': 7}
# 11                 Sequential      {'learning_rate': 0.01, 'max_depth': 7}
#
#             MAE           MSE          RMSE
# 0   3573.904714  8.310095e+08  28827.235464
# 1   3501.157105  8.284939e+08  28783.569330
# 2   3490.777214  8.295889e+08  28802.585150
# 3   3170.033665  8.283417e+08  28780.925975
# 4   3571.910013  1.946512e+09  44119.290696
# 5   2725.713958  5.593129e+08  23649.797073
# 6   3435.953126  1.203068e+09  34685.273122
# 7   2917.888813  8.227691e+08  28683.951552
# 8   1696.806042  8.336853e+08  28873.609681
# 9   3018.869101  7.228945e+08  26886.697561
# 10  2392.479085  8.003849e+08  28291.074770
# 11  3237.478904  8.249821e+08  28722.501579

# %%
n_estimators = 300
max_depth = 10

# Train and evaluate the RandomForestRegressor
model = RandomForestRegressor(n_estimators=n_estimators, max_depth=max_depth)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# Calculate evaluation metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

# Print the evaluation metrics
print('MAE:', mae)
print('MSE:', mse)
print('RMSE:', rmse)
# Out:
# MAE: 2703.490320565951
# MSE: 528546201.7995799
# RMSE: 22990.132705131997

# %%
import joblib
joblib.dump(model,"RFR.pkl")
# Out:
# ['RFR.pkl']

# %%
#load the dataset as pandas dataframe
df_test=pd.read_csv("/content/test.csv")
df_test.head()
# Out:
#        vidid    views likes dislikes comment   published  duration category
# 0   VID_1054   440238  6153      218    1377  2017-02-18   PT7M29S        B
# 1  VID_18629  1040132  8171      340    1047  2016-06-28   PT6M29S        F
# 2  VID_13967    28534    31       11       1  2014-03-10  PT37M54S        D
# 3  VID_19442  1316715  2284      250     274  2010-06-05   PT9M55S        G
# 4    VID_770  1893173  2519      225     116  2016-09-03    PT3M8S        B

# %%
df_test.shape
# Out:
# (8764, 8)

# %%
def PreProcess(df):
  """
  PreProcess the test data as in train data
  Args:
      df : pandas DataFrame
  returns preprocessed numpy array for prediction
  """

  df["category"]=LE.fit_transform(df["category"])
  df["vidid"]=LE.fit_transform(df["vidid"])
  df["published"]=LE.fit_transform(df["published"])
  df.comment=df.comment.apply(lambda x: 0 if x=="F" else x)
  df.views=df.views.apply(lambda x: 0 if x=="F" else x)
  df.likes=df.likes.apply(lambda x: 0 if x=="F" else x)
  df.dislikes=df.dislikes.apply(lambda x: 0 if x=="F" else x)
  df.comment=df.comment.astype("int64")
  df.dislikes=df.dislikes.astype("int64")
  df.likes=df.likes.astype("int64")
  df.views=df.views.astype("int64")

  def funsec(string):

    pattern = r'PT(?:(?P<hours>\d+)H)?((?P<minutes>\d+)M)?((?P<seconds>\d+)S)?'
    hours=0
    minutes=0
    seconds=0
    match = re.search(pattern, string)
    if match:
        hours = match.group('hours') if match.group('hours') else 0
        minutes = match.group('minutes') if match.group('minutes') else 0
        seconds = match.group('seconds') if match.group('seconds') else 0
        return int(hours)*3600+int(minutes)*60+int(seconds)
  df["duration"]=df["duration"].apply(funsec)
  Scaler=MinMaxScaler()
  df=Scaler.fit_transform(df)
  return df

# %%
df_test=PreProcess(df_test)

# %%
df_test,type(df_test)
# Out:
# (array([[2.64749515e-02, 1.95532926e-03, 1.92237996e-02, ...,
#          9.74857685e-01, 1.07451417e-02, 1.42857143e-01],
#         [4.02715965e-01, 4.61977507e-03, 2.55286311e-02, ...,
#          8.66698292e-01, 9.29309552e-03, 7.14285714e-01],
#         [1.88634029e-01, 1.26734551e-04, 9.68532080e-05, ...,
#          4.79127135e-01, 5.49115462e-02, 4.28571429e-01],
#         ...,
#         [4.18920461e-01, 8.40200239e-03, 1.43905121e-02, ...,
#          8.65749526e-01, 1.03821302e-02, 7.14285714e-01],
#         [8.07828369e-01, 3.17506604e-03, 5.12072284e-03, ...,
#          8.20683112e-01, 4.59814622e-03, 4.28571429e-01],
#         [9.34953783e-01, 2.35267721e-05, 3.74915644e-05, ...,
#          9.47817837e-01, 1.47382687e-02, 4.28571429e-01]]),
#  numpy.ndarray)

# %%
model_file = joblib.load('RFR.pkl')
y_pred=model_file.predict(df_test)

# %%
result=pd.DataFrame(y_pred,columns=["adviews"])

# %%
result.to_csv("Prediction.csv")
